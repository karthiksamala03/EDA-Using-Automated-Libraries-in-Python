# %% [markdown]
# To perform the EDA we need to type several lines of code.
# Here auto-visualization library comes into the play,
# which can perform all these tasks using just 1 line of code.
# Some of these auto-visualization tools are:
#
# 1. Pandas-Profiling
# 2. Sweetviz
# 3. Autoviz
# 4. D-Tale

# %% [markdown]
# ### In this Notebook will discuss about D-Tale

# %%
# !pip install dtale
# Out:
# ...
#   Created wheel for dash-colorscales: filename=dash_colorscales-0.0.4-py3-none-any.whl size=62582 sha256=7c0adb6e6a34bd939c718d852c11ad6b5edc412d518193e40e9fd551ec33a405
#   Stored in directory: c:\users\use\appdata\local\pip\cache\wheels\ec\32\ec\dc8a1aa820182edf280a5e26c76fc9493ae29e196735708de2
# ...
#   Created wheel for dash-daq: filename=dash_daq-0.5.0-py3-none-any.whl size=669714 sha256=c17af7c57f0b013be306910e7709d0aaabd1cdd5c27d220ffc3559a6e253c001
#   Stored in directory: c:\users\use\appdata\local\pip\cache\wheels\53\73\ea\8a422aab5cab848d88653ed3087c1fa05553c3fbd67fb6ab75
# Successfully built dash-colorscales dash-daq
# ...
#   Attempting uninstall: missingno
#     Found existing installation: missingno 0.5.1
#     Uninstalling missingno-0.5.1:
#       Successfully uninstalled missingno-0.5.1
# ...

# %%
import pandas as pd
import dtale

# %%
df = pd.read_csv('stud.csv')
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
import seaborn as sns
df = sns.load_dataset("titanic")

# %%
d = dtale.show(df)
d.open_browser()
# Out:
# C:\Users\use\anaconda3\lib\site-packages\dtale\views.py:725: FutureWarning:
#
# ['embarked', 'class', 'deck', 'embark_town'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#
# C:\Users\use\anaconda3\lib\site-packages\dtale\views.py:1929: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#
# C:\Users\use\anaconda3\lib\site-packages\dtale\views.py:1929: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#
# C:\Users\use\anaconda3\lib\site-packages\dtale\views.py:1929: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#
# C:\Users\use\anaconda3\lib\site-packages\dtale\views.py:1929: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#
# ...
